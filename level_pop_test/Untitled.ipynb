# %%
save last species densities "He+_pops.dat" "He+[:]"
# Out:
# 'species densities He+_pops.dat He+[:]' was not found in history, as a file, url, nor in the user namespace.

# %%
save last species densities "He+_pops.dat" "He+[:]"
# Out:
# 'species densities He+_pops.dat He+[:]' was not found in history, as a file, url, nor in the user namespace.

# %%
save last species densities "He+_pops.dat" "He+[:]"
